# %%
import pandas as pd

responses = pd.DataFrame({
    "model": ["ChatGPT", "Claude", "Perplexity", "Gemini"],
    "brand_mentioned": [True, True, False, True],
    "sentiment": ["positive", "positive", "none", "neutral"]
})

responses
# Out:
#         model  brand_mentioned sentiment
# 0     ChatGPT             True  positive
# 1      Claude             True  positive
# 2  Perplexity            False      none
# 3      Gemini             True   neutral

# %%
responses.shape
# Out:
# (4, 3)

# %%
responses.columns
# Out:
# Index(['model', 'brand_mentioned', 'sentiment'], dtype='str')

# %%
responses["model"]
# Out:
# 0       ChatGPT
# 1        Claude
# 2    Perplexity
# 3        Gemini
# Name: model, dtype: str

# %%
responses["brand_mentioned"] == True
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# Name: brand_mentioned, dtype: bool

# %%
responses[responses["brand_mentioned"] == True]
# Out:
#      model  brand_mentioned sentiment
# 0  ChatGPT             True  positive
# 1   Claude             True  positive
# 3   Gemini             True   neutral

# %%
responses[responses["sentiment"] == "positive"]
# Out:
#      model  brand_mentioned sentiment
# 0  ChatGPT             True  positive
# 1   Claude             True  positive

# %%
responses[(responses["brand_mentioned"] == True) & (responses["sentiment"] == "positive")]
# Out:
#      model  brand_mentioned sentiment
# 0  ChatGPT             True  positive
# 1   Claude             True  positive

# %%
responses[responses["sentiment"] == "neutral"]
# Out:
#     model  brand_mentioned sentiment
# 3  Gemini             True   neutral
